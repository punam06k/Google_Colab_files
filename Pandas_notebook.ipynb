# %%
# Import library
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Upload the file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-36895c83-3297-46d1-82ab-690739769430" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36895c83-3297-46d1-82ab-690739769430">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Reading a dataset and display
df = pd.read_csv('Salaries.csv') 
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# To display the all rows of dataset
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# List first 5 records
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# List last 5 records
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
# Return randomly one row
df.sample()
# Out:
#         rank discipline  phd  service     sex  salary
# 43  AsstProf          B    5        0  Female   77000

# %%
# List first 10 records
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
# List last 15 records
df.tail(15)
# Out:
#          rank discipline  phd  service     sex  salary
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
# Returns randomly 6 rows
df.sample(6)
# Out:
#          rank discipline  phd  service     sex  salary
# 61  AssocProf          B   13       10  Female  103750
# 26       Prof          A   38       19    Male  148750
# 45       Prof          B   25       25  Female  140096
# 10       Prof          B   39       33    Male  128250
# 20   AsstProf          B    4        4    Male   92000
# 42   AsstProf          B    4        2  Female   80225

# %%
# Check a perticular column type
df['salary'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Data Attributes

# %%
# List the column names
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
# List the types of the columns
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
# List the row labels and column names
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
# Return the number of dimensions
df.ndim
# Out:
# 2

# %%
# Return the number of elements
df.size
# Out:
# 468

# %%
# Return the number of rows and columns
df.shape
# Out:
# (78, 6)

# %%
# Return the number of rows(records)
df.shape[0]
# Out:
# 78

# %%
# Return the number of columns
df.shape[1]
# Out:
# 6

# %%
# Display the numpy representation of panda
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %% [markdown]
# Data Methods

# %%
# Generate the desciptive statistics only numeric columns only
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
# Return max values for all columns
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
# Return min values for all columns
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
# Return mean for a perticular column
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
# Return median for a perticular column
df['phd'].median()
# Out:
# 18.5

# %%
# Return standard deviation for a perticular column
df['service'].std()
# Out:
# 12.139767682042327

# %%
# Return the mean values of first 40 records
df.head(40).mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# phd            22.775
# service        18.525
# salary     115394.025
# dtype: float64

# %%
# Return the basic statistics for a perticular column
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
# Return a series containing counts of unique values
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
# Group data using rank
df_rank = df.groupby(['rank'])

# %%
# Calculate mean value for each numeric column per each group
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
# Group data using discipline and calculate std. deviation for each numeric column per each group
df_discipline_std = df.groupby(['discipline']).std()
df_discipline_std
# Out:
#                   phd    service        salary
# discipline
# A           12.971367  12.584823  26000.183807
# B           12.013349  11.867640  27805.722287

# %%
# Calculate the mean of salary for each professor column
df.groupby(['rank'])[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
# Calculate the mean of service for each discipline column
df.groupby(['discipline'])[['service']].mean()
# Out:
#               service
# discipline
# A           15.722222
# B           14.476190

# %%
# calculate the mean of salary for each sex column
df.groupby(['sex'])[['salary']].mean()
# Out:
#                salary
# sex
# Female  101002.410256
# Male    115045.153846

# %% [markdown]
# Data Filtering

# %%
df_salary = df[df['salary'] < 120000]
df_salary
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# ...

# %%
df[(df['salary'] > 120000) & (df['rank'] == 'Prof') & (df['discipline'] == 'B')]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 44  Prof          B   23       19  Female  151768
# 45  Prof          B   25       25  Female  140096
# 49  Prof          B   17       18  Female  122960
# 51  Prof          B   20       14  Female  127512
# 58  Prof          B   36       26  Female  144651
# 72  Prof          B   24       15  Female  161101
# 75  Prof          B   17       17  Female  124312

# %%
df[(df['salary']<=150000) & (df['salary']>=100000) & (df['rank']=='Prof') & (df['sex']=='Female') & (df['discipline']=='A')]
# Out:
#     rank discipline  phd  service     sex  salary
# 40  Prof          A   39       36  Female  137000
# 52  Prof          A   12        0  Female  105000
# 65  Prof          A   36       19  Female  117555
# 69  Prof          A   28        7  Female  116450
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
# iloc function helps us to select a specific row or column from the dataset.
df.iloc[[5,9,11,15,18,20],[0,3,5]]
# Out:
#         rank  service  salary
# 5       Prof       20  122400
# 9       Prof       51   57800
# 11      Prof       23  134778
# 15      Prof        3  150480
# 18      Prof        7  107300
# 20  AsstProf        4   92000

# %%
df.iloc[25:31,:]
# Out:
#          rank discipline  phd  service   sex  salary
# 25       Prof          B   35       31  Male   99418
# 26       Prof          A   38       19  Male  148750
# 27       Prof          A   45       43  Male  155865
# 28   AsstProf          B    7        2  Male   91300
# 29       Prof          B   21       20  Male  123683
# 30  AssocProf          B    9        7  Male  107008

# %%
df.iloc[[1,6,35,23,17,10,3],:]
# Out:
#          rank discipline  phd  service   sex  salary
# 1        Prof          A   12        6  Male   93000
# 6   AssocProf          A   20       17  Male   81285
# 35       Prof          B   28       23  Male  126933
# 23   AsstProf          A    2        0  Male   85000
# 17   AsstProf          B    4        0  Male   92000
# 10       Prof          B   39       33  Male  128250
# 3        Prof          A   40       31  Male  131205

# %%
df.iloc[24:32,:]
# Out:
#          rank discipline  phd  service   sex  salary
# 24       Prof          A   30       23  Male   91100
# 25       Prof          B   35       31  Male   99418
# 26       Prof          A   38       19  Male  148750
# 27       Prof          A   45       43  Male  155865
# 28   AsstProf          B    7        2  Male   91300
# 29       Prof          B   21       20  Male  123683
# 30  AssocProf          B    9        7  Male  107008
# 31       Prof          B   22       21  Male  155750

# %%
#To get the frequency count of each unique value in the 'discipline' variable of 'df' dataframe
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
#Selecting multiple columns from a dataframe.
#For selecting multiple columns, the column names must be specified in a list (box bracket)
df[['salary','phd','service']].head()
# Out:
#    salary  phd  service
# 0  186960   56       49
# 1   93000   12        6
# 2  110515   23       20
# 3  131205   40       31
# 4  104800   20       18

# %%
print(df['salary'].head())
# Out:
# 0    186960
# 1     93000
# 2    110515
# 3    131205
# 4    104800
# Name: salary, dtype: int64

# %%
df[['salary','service']].mean()
# Out:
# salary     108023.782051
# service        15.051282
# dtype: float64
